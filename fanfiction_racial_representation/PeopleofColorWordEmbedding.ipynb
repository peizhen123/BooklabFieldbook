# %%
import pandas as pd

# %%
read_file = pd.read_csv (r'/Users/wupeizhen/Desktop/Desktop_PeizhenWu_Macbookair/2021 Fall/ENGL 586/Final 586/data-mining-script-for-ao3-master/PeopleofColor.txt', error_bad_lines=False)
read_file.to_csv (r'/Users/wupeizhen/Desktop/Desktop_PeizhenWu_Macbookair/2021 Fall/ENGL 586/Final 586/data-mining-script-for-ao3-master/PeopleofColor.csv', index=None)
# Out:
# b'Skipping line 101: expected 549 fields, saw 1199\n'
# b'Skipping line 1839: expected 549 fields, saw 1478\nSkipping line 2346: expected 549 fields, saw 726\nSkipping line 2446: expected 549 fields, saw 1199\n'
# b'Skipping line 4184: expected 549 fields, saw 1478\n'
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (321,322,323,324,325,326,327,328,329,330,331,332,333,334,335,336,337,338,339,340,341,342,343,344,345,346,347,348,349,350,351,352,353,354,355,356,357,358,359,360,361,362,363,364,365,366,367,368,369,370,371,372,373,374,375,376,377,378,379,380,381,382,383,384,385,386,387,388,389,390,391,392,393,394,395,396,397,398,399,400,401,402,403,404,405,406,407,408,409,410,411,412,413,414,415,416,417,418,419,420,421,422,423,424,425,426,427,428,429,430,431,432,433,434,435,436,437,438,439,440,441,442,443,444,445,446,447) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
import gensim
from gensim.models import Word2Vec

# %%
pip install gensim
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 20.1; however, version 21.3.1 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.6/bin/python3.6 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
import gensim
from gensim.models import Word2Vec

# %%
import pandas as pd
rev = pd.read_csv(r"/Users/wupeizhen/Desktop/Desktop_PeizhenWu_Macbookair/2021 Fall/ENGL 586/Final 586/data-mining-script-for-ao3-master/PeopleofColor.csv")
rev.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (321,322,323,324,325,326,327,328,329,330,331,332,333,334,335,336,337,338,339,340,341,342,343,344,345,346,347,348,349,350,351,352,353,354,355,356,357,358,359,360,361,362,363,364,365,366,367,368,369,370,371,372,373,374,375,376,377,378,379,380,381,382,383,384,385,386,387,388,389,390,391,392,393,394,395,396,397,398,399,400,401,402,403,404,405,406,407,408,409,410,411,412,413,414,415,416,417,418,419,420,421,422,423,424,425,426,427,428,429,430,431,432,433,434,435,436,437,438,439,440,441,442,443,444,445,446,447) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                          Harry took Dumbledore’s arm  \
# 0    Put some pants on. Skirts are for WOMEN not men
# 1  Peter looked at the comment in surprise. He di...
# ...

# %%
import pandas as pd
rev = pd.read_csv(r"/Users/wupeizhen/Desktop/Desktop_PeizhenWu_Macbookair/2021 Fall/ENGL 586/Final 586/data-mining-script-for-ao3-master/PeopleofColor.csv")
#rev.head()
